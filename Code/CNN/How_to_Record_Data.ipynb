# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>This Notebook will Document how to Collect Data.</h2>
# </div>
#
# Ensure you are running Geometry Dash 2.1 with Megahack 7.1 installed.
# Follow these tutorials to start:
#
# 1.   [Install GD 2.1](https://www.youtube.com/watch?v=JMBn04BWTJc)
# 2.   [Install Megahack](https://www.youtube.com/watch?v=Df77YZZVp1k)
#
# Now, open up geometry dash. Press TAB to open up the MegaHack Menu.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# It should look something like this.
#
# We are first going to take regular "live game" screenshots.
#
# Enable the following settings: If you cannot find a setting, type and it should be highlighted.
#
# *   Icons
# *   Set "FPS Bypass" to 30. (This will make taking screenshots easier)
# *   Copy Hack
#
# Next, go into the icon selector (face icon to the left of play button)
#
# Keep all default icons (first option from the left for each tab).
# Change both colors to white.
#
# ![2024 Jul 04 21-34-231.png](data:image/png;base64,...)

# %% [markdown]
# We are now going to configure keybindings for our python script.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In "Shortcuts," find "Restart level" and click it.
# Enter "R" into the "Enter Keybind" box.
# Press "Set".
#
# In "Capture," select "Screenshot" and set it to "T" with the same steps as above.
#
# Now, find the "Frame Stepper" option in the "Level" Tab.
#
#
# ![image.png](data:image/png;base64,...)
#
# Configure it as follows.

# %% [markdown]
# We will now adjust graphics settings.
# In the main menu, press the "cog" at the bottom of the screen:
#
# ![image.png](data:image/png;base64,...)
#
# Go to "Graphics." Set windowed resolution to 1920x1440 and texture quality to low. (This is assuming your laptop screen is 2560x1600. I'm not sure how well this works on other laptop screen sizes).

# %% [markdown]
# Next, go into a level you want to record.
#
# * Using the macro section, type in a name for the Macro you will rercord (this is for future refreence).
# * Select "Record."
# * Set "Accuracy" to "Frame Fixes"
#
# ![image.png](data:image/png;base64,...)
#
# Now enter into the level you want to record and play through in practice mode.
#
# Once you have completed the level, open up the menu again and press "Save."
#
# You can now restart the level. Turn on "Frame Stepper" and set the macro to "Replay."

# %% [markdown]
# Now open and run the file "screenshot_macro.py". Adjust the in-file settings (ie level length) to match. You can also run it from below:

# %%
import keyboard as kb
import time
import math
import sys

#it takes 50 frames to go through an entire "screen" of objects at 30fps, on lowest aspect ratio
#framesteppers: e goes forwards.

def run_macro():
    for i in range(initial_frames):
        kb.press_and_release(forward_step)
        time.sleep(0.05)
    for i in range(n_screenshots):
        for j in range(frames_interval):
            #forward step a set number of times
            kb.press_and_release(forward_step)
            time.sleep(0.05)
        kb.press_and_release(screenshot)
        time.sleep(0.7)

def stop_macro():
    print("Stopping macro. ")
    sys.exit()

#KEYBINDINGS (adjust depending on what you are doing)
forward_step = "e"
backward_step = "q"
screenshot = "t"

#CAPTURE SETTINGS
initial_frames = 15 #number of frames to skip at the start
frames_interval = 50 #number of frames between screenshots
level_length = 85 #level length in seconds, will be used to prevent the macro from running too long
fps = 30 #frames per second for the game

n_screenshots = math.floor(level_length*fps/frames_interval) #number of screenshots to be taken

print("Macro working. Press space to begin.")
kb.wait('space')
print("Macro activating in 5s. Tab into the level.")
time.sleep(5)
# kb.on_press_key("space", stop_macro())
run_macro()

# %% [markdown]
# Now, navigate to your game's directory using the "Browse Local Files" option in steam:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Take all the screenshots and put it into a folder (or however you want to store it).
#
# We will now create "labeled screenshots" for the same level.
#
# Open up the MegaHack panel again, and enable these settings:
#
# * Force Don't Enter/Fade (2 options)
# * Hide Attempts
# * No Background Flash
# * No Dash Trail
# * No Effect Circle
# * No Ghost Trail
# * No Glow
# * No Orb Ring
# * No Particles
# * No Portal Lighting
# * No Pulse
# * No Respawn Flash
# * No Wave Pulse
# * Trail Always Off
#
# Next, enable hitboxes and change the configuration as follows:
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Next, Turn on "Show Layout." Set "Ground Color" to white (#FFFFFF) and "BG Color" to black (#000000).
#
# Then, make a copy of the level and open up the editor.
#
# *   Main levels can be found in the custom levels menu by searching "____ copy"
# *   All custom levels will be copyable with the copy hack.
#
# ![2024 Jul 04 22-00-033.png](data:image/png;base64,...)

# %% [markdown]
# This menu can be found by pressing the gear button in the top right. Select the square under "Line" and drag the slider under "Opacity" to 0.

# %% [markdown]
# Now, navigate to the game's directory and open the Resources Folder.
#
# Download the following images and copy it directlty into the folder, repacing the original textures.
#
# https://drive.google.com/drive/folders/1VRAdrvyIA5mOasj2u-H9HjrkyH6jVQE9?usp=drive_link
#
# Now repeat the same steps as before to take screenshots.
